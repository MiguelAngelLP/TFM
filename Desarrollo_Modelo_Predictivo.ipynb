# %%
#!pip install azure.storage.blob
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 27, Finished, Available, Finished)

# %%
#!pip install matplotlib
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 28, Finished, Available, Finished)

# %%
#!pip install statsmodels
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 29, Finished, Available, Finished)

# %%
#!pip install pmdarima
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 30, Finished, Available, Finished)

# %%
#!pip install tensorflow
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 31, Finished, Available, Finished)

# %%
from azure.storage.blob import BlobServiceClient
import pandas as pd
import pyarrow.parquet as pq
import io

connection_string = 'BlobEndpoint=https://adltfmunir.blob.core.windows.net/;QueueEndpoint=https://adltfmunir.queue.core.windows.net/;FileEndpoint=https://adltfmunir.file.core.windows.net/;TableEndpoint=https://adltfmunir.table.core.windows.net/;SharedAccessSignature=sv=2022-11-02&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2024-12-31T05:31:14Z&st=2024-08-18T21:31:14Z&spr=https&sig=Qq%2BYE9Ij8%2FvrfTu8dS0kxslJmOtlVFqx0lSnUsPQRlo%3D'  # Reemplaza con tu cadena de conexión
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
container_name = 'file'
blob_prefix = "Casa_Sensores.parquet"
container_client = blob_service_client.get_container_client(container_name)
blob_list = container_client.list_blobs(name_starts_with=blob_prefix)

dataframes = []

for blob in blob_list:
    blob_client = container_client.get_blob_client(blob)
    stream = io.BytesIO()
    blob_client.download_blob().download_to_stream(stream)
    stream.seek(0)
    df = pd.read_parquet(stream)
    dataframes.append(df)

df_datos_sensores = pd.concat(dataframes, ignore_index=True)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 32, Finished, Available, Finished)

# %%
#Se filtran las columnas requeridas
df_datos_sensores = df_datos_sensores[[
'Fecha','Hora', 'Consumo_Total_kWhs', 'Refrigeradora',
'Tomacorrientes_Cocina', 'Cocina_Induccion',
'Tomacorriente_PB_y_Lavadora', 'Tomacorriente_PA',
'AireAcondicionado_Cuarto1', 'AireAcondicionado_Cuarto2',
'AireAcondicionado_Oficina', 'AireAcondicionado_Sala', 'Iluminacion_PB',
'Iluminacion_PA', 'Bomba_Agua', 'Balance',
'CuartoPrincipal_Temperatura_C', 'CuartoPrincipal_Humedad_Relativa_%',
#'Cuarto2_Temperatura_C', 'Cuarto2_Humedad_Relativa_%',
#'Oficina_Temperatura_C', 'Oficina_Humedad_Relativa_%',
'Sala_Temperatura_C', 'Sala_Humedad_Relativa_%',
'Cocina_Temperatura_C','Cocina_Humedad_Relativa_%',
'PatioLateral_Temperatura_C','PatioLateral_Humedad_Relativa_%',
#'PatioTrasero_Temperatura_C','PatioTrasero_Humedad_Relativa_%',
'ExteriorFachada_Temperatura_C','ExteriorFachada_Humedad_Relativa_%'
]]
#Nota: Las variables comentadas pertenecen a los ultimos sensores comprados, no tiene mucha historia
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 33, Finished, Available, Finished)

# %%
df_datos_sensores.shape
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 34, Finished, Available, Finished)
# (10249, 26)

# %%
# Primer modelo considerando únicamente el consumo total:
datos_modelo = df_datos_sensores[['Fecha', 'Hora', 'Consumo_Total_kWhs']]
datos_modelo = datos_modelo.copy()
datos_modelo.loc[:, 'FechaHora']  = datos_modelo['Fecha'] + ' ' + datos_modelo['Hora']
datos_modelo.head(5)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 35, Finished, Available, Finished)
#         Fecha              Hora  Consumo_Total_kWhs  \
# 0  2023-06-26  13:00:00.0000000              0.2214
# 1  2023-06-26  14:00:00.0000000              0.1241
# 2  2023-06-26  15:00:00.0000000              0.1081
# 3  2023-06-26  16:00:00.0000000              0.1291
# 4  2023-06-26  17:00:00.0000000              0.1146
#
#                      FechaHora
# 0  2023-06-26 13:00:00.0000000
# 1  2023-06-26 14:00:00.0000000
# 2  2023-06-26 15:00:00.0000000
# 3  2023-06-26 16:00:00.0000000
# 4  2023-06-26 17:00:00.0000000

# %%
# Validamos cuantos registros se tienen por fecha:
conteo_por_fecha = datos_modelo.groupby('Fecha').size().reset_index(name='Repeticiones')
print(f"Porcentaje válido: {100*conteo_por_fecha[conteo_por_fecha['Repeticiones'] == 24].shape[0]/conteo_por_fecha.shape[0]}.")
print('Fechas a excluir:')
fechas_excluir = conteo_por_fecha[conteo_por_fecha['Repeticiones'] != 24]['Fecha']
fechas_excluir
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 36, Finished, Available, Finished)
# Porcentaje válido: 99.53271028037383.
# Fechas a excluir:
# 0      2023-06-26
# 427    2024-08-26
# Name: Fecha, dtype: object

# %%
datos_modelo= datos_modelo[~datos_modelo['Fecha'].isin(fechas_excluir)]
datos_modelo = datos_modelo.drop(['Fecha', 'Hora'], axis=1)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 37, Finished, Available, Finished)

# %%
display(datos_modelo)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 38, Finished, Available, Finished)
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:604: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# SynapseWidget(Synapse.DataFrame, f1a0a5d2-94c3-4e15-b748-19341a9f4f97)

# %% [markdown]
# Preprocesamiento de información

# %%
# Convertir 'FechaHora' a datetime y configurarlo como índice
datos_modelo['FechaHora'] = pd.to_datetime(datos_modelo['FechaHora'])
datos_modelo.set_index('FechaHora', inplace=True)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 39, Finished, Available, Finished)

# %%
import matplotlib.pyplot as plt
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 40, Finished, Available, Finished)

# %%
# Definimos una función para graficar las series de tiempo.
def plot_series(data, title='Evolución del Consumo', xlabel='FechaHora', ylabel='Consumo_Total_kWhs'):
    plt.figure(figsize=(12, 6))
    plt.plot(data, label='Consumo Total', color='blue')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()
    plt.show()

# Llamada a la función
plot_series(datos_modelo['Consumo_Total_kWhs'])
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 41, Finished, Available, Finished)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

def decompose_series(data, model='additive'):
    decomposition = seasonal_decompose(data, model=model)
    fig, axs = plt.subplots(4, 1, figsize=(12, 12), sharex=True)
    axs[0].plot(data, label='Original')
    axs[0].set_title('Original')
    axs[1].plot(decomposition.trend, label='Tendencia')
    axs[1].set_title('Tendencia')
    axs[2].plot(decomposition.seasonal, label='Estacionalidad')
    axs[2].set_title('Estacionalidad')
    axs[3].plot(decomposition.resid, label='Residual')
    axs[3].set_title('Residual')
    plt.tight_layout()
    plt.show()

# Llamada a la función
decompose_series(datos_modelo['Consumo_Total_kWhs'])
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 42, Finished, Available, Finished)

# %%
# Verifica si la serie es estacionaria:
from statsmodels.tsa.stattools import adfuller

def check_stationarity(data):
    result = adfuller(data.dropna())
    print(f'ADF Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    print('Critial Values:')
    for key, value in result[4].items():
        print(f'   {key}: {value}')
    if result[1] <= 0.05:
        print("La serie es estacionaria")
    else:
        print("La serie no es estacionaria")

# Llamada a la función
check_stationarity(datos_modelo['Consumo_Total_kWhs'])
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 43, Finished, Available, Finished)
# ADF Statistic: -10.903940080381197
# p-value: 1.140670021146421e-19
# Critial Values:
#    1%: -3.4309920247732566
#    5%: -2.8618237373353677
#    10%: -2.5669210282407273
# La serie es estacionaria

# %% [markdown]
# # Modelo Arima

# %%
# Dividimos en train y test:
train_size = int(len(datos_modelo) * 0.99)
test_size = len(datos_modelo) - train_size

# Dividir el dataset
train, test = datos_modelo['Consumo_Total_kWhs'][:train_size], datos_modelo['Consumo_Total_kWhs'][train_size:]

print(f"Tamaño del conjunto de entrenamiento: {len(train)}")
print(f"Tamaño del conjunto de prueba: {len(test)}")
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 24, Finished, Available, Finished)
# Tamaño del conjunto de entrenamiento: 10121
# Tamaño del conjunto de prueba: 103

# %%
# Optimizamos el modelo:
#!pip install pmdarima
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 25, Finished, Available, Finished)

# %%
import pmdarima as pm

def optimize_arima(train_data):
    # Encuentra los mejores parámetros para el modelo ARIMA
    model = pm.auto_arima(train_data, seasonal=True, m=24,
                          trace=True, error_action='ignore',
                          suppress_warnings=True,
                          stepwise=True)
    print(model.summary())
    return model
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 26, Finished, Available, Finished)

# %%
# Ajusta el modelo ARIMA optimizado
arima_model = optimize_arima(train)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 26, Submitted, Running, Running)
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[24] intercept   : AIC=inf, Time=115.20 sec
#  ARIMA(0,1,0)(0,0,0)[24] intercept   : AIC=9830.799, Time=3.06 sec
#  ARIMA(1,1,0)(1,0,0)[24] intercept   : AIC=8969.561, Time=10.47 sec
#  ARIMA(0,1,1)(0,0,1)[24] intercept   : AIC=8276.350, Time=12.13 sec
#  ARIMA(0,1,0)(0,0,0)[24]             : AIC=9828.799, Time=0.56 sec
#  ARIMA(0,1,1)(0,0,0)[24] intercept   : AIC=8457.236, Time=3.69 sec
#  ARIMA(0,1,1)(1,0,1)[24] intercept   : AIC=inf, Time=54.98 sec
#  ARIMA(0,1,1)(0,0,2)[24] intercept   : AIC=8207.341, Time=74.65 sec
#  ARIMA(0,1,1)(1,0,2)[24] intercept   : AIC=inf, Time=301.04 sec
#  ARIMA(0,1,0)(0,0,2)[24] intercept   : AIC=9653.925, Time=44.83 sec
#  ARIMA(1,1,1)(0,0,2)[24] intercept   : AIC=inf, Time=335.00 sec
#  ARIMA(0,1,2)(0,0,2)[24] intercept   : AIC=inf, Time=256.16 sec
#  ARIMA(1,1,0)(0,0,2)[24] intercept   : AIC=8943.887, Time=88.82 sec
#  ARIMA(1,1,2)(0,0,2)[24] intercept   : AIC=inf, Time=316.26 sec
#  ARIMA(0,1,1)(0,0,2)[24]             : AIC=8205.341, Time=19.65 sec
#  ARIMA(0,1,1)(0,0,1)[24]             : AIC=8274.350, Time=4.69 sec
#  ARIMA(0,1,1)(1,0,2)[24]             : AIC=inf, Time=104.54 sec
#  ARIMA(0,1,1)(1,0,1)[24]             : AIC=inf, Time=20.91 sec
#  ARIMA(0,1,0)(0,0,2)[24]             : AIC=9651.925, Time=12.95 sec
#  ARIMA(1,1,1)(0,0,2)[24]             : AIC=inf, Time=44.84 sec
#  ARIMA(0,1,2)(0,0,2)[24]             : AIC=inf, Time=36.36 sec
#  ARIMA(1,1,0)(0,0,2)[24]             : AIC=8941.887, Time=22.82 sec
#  ARIMA(1,1,2)(0,0,2)[24]             : AIC=inf, Time=55.65 sec
#
# Best model:  ARIMA(0,1,1)(0,0,2)[24]
# Total fit time: 1939.434 seconds
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                10121
# Model:             SARIMAX(0, 1, 1)x(0, 0, [1, 2], 24)   Log Likelihood               -4098.671
# Date:                                 Mon, 09 Sep 2024   AIC                           8205.341
# Time:                                         03:27:06   BIC                           8234.231
# Sample:                                     06-27-2023   HQIC                          8215.114
#                                           - 08-21-2024
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5723      0.006   -102.435      0.000      -0.583      -0.561
# ma.S.L24       0.1276      0.008     15.941      0.000       0.112       0.143
# ma.S.L48       0.0803      0.008      9.744      0.000       0.064       0.096
# sigma2         0.1316      0.001    143.552      0.000       0.130       0.133
# ===================================================================================
# Ljung-Box (L1) (Q):                 230.20   Jarque-Bera (JB):             20378.20
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.58   Skew:                             1.55
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Una vez que el modelo ARIMA está ajustado, realizamos predicciones y evalúamos el rendimiento en el conjunto de prueba:
from sklearn.metrics import mean_squared_error

def forecast_and_evaluate(model, train_data, test_data, steps):
    # Realizamos las predicciones
    forecast = model.predict(n_periods=steps)
    
    # Evaluamos el rendimiento del modelo
    mse = mean_squared_error(test_data, forecast)
    print(f'Error cuadrático medio (MSE) en el conjunto de prueba: {mse}')
    
    # Real VS Predicho
    plt.figure(figsize=(12, 6))
    plt.plot(train_data.index, train_data, label='Entrenamiento')
    plt.plot(test_data.index, test_data, label='Prueba')
    plt.plot(test_data.index, forecast, label='Pronóstico', color='red')
    plt.title('Pronóstico con ARIMA Optimizado')
    plt.xlabel('FechaHora')
    plt.ylabel('Consumo Total')
    plt.legend()
    plt.show()

# Número de períodos de pronóstico
steps = len(test)

# Llamada a la función
forecast_and_evaluate(arima_model, train, test, steps)
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# Error cuadrático medio (MSE) en el conjunto de prueba: 0.15439595613272306

# %% [markdown]
# # Red Neuronal

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Escalamos los datos entre 0 y 1 para entrenar el modelo:
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train.values.reshape(-1, 1))
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 28, Finished, Available, Finished)

# %%
# Función para crear secuencias de entrada (X) y salida (y)
def create_sequences(data, time_step=24):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 29, Finished, Available, Finished)

# %%
# Crear secuencias con 24 pasos de tiempo
time_step = 24
X_train, y_train = create_sequences(train_scaled, time_step)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 30, Finished, Available, Finished)
# 2024-09-09 03:29:55.158619: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Creamos el modelo LSTM
early_stopping = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True, verbose=1)

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 31, Finished, Available, Finished)
# 2024-09-09 03:30:34.813421: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-09 03:30:34.814131: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Reshape de los datos de entrada
X_train_reshaped = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# Entrenar el modelo
model.fit(X_train_reshaped, y_train, epochs=50, batch_size=32, shuffle=False, verbose=1, 
callbacks=[early_stopping])
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 32, Finished, Available, Finished)
# Epoch 1/50
# 316/316 [==============================] - 37s 97ms/step - loss: 0.0087
# Epoch 2/50
# 316/316 [==============================] - 29s 92ms/step - loss: 0.0075
# Epoch 3/50
# 316/316 [==============================] - 29s 93ms/step - loss: 0.0073
# Epoch 4/50
# 316/316 [==============================] - 31s 98ms/step - loss: 0.0073
# Epoch 5/50
# 316/316 [==============================] - 30s 94ms/step - loss: 0.0073
# Epoch 6/50
# 316/316 [==============================] - 31s 99ms/step - loss: 0.0073
# Epoch 7/50
# 316/316 [==============================] - 32s 100ms/step - loss: 0.0072
# Epoch 8/50
# 316/316 [==============================] - 32s 101ms/step - loss: 0.0072
# Epoch 9/50
# 316/316 [==============================] - 30s 94ms/step - loss: 0.0072
# Epoch 10/50
# 316/316 [==============================] - 31s 99ms/step - loss: 0.0072
# Epoch 11/50
# 316/316 [==============================] - 30s 94ms/step - loss: 0.0072
# Epoch 12/50
# 316/316 [==============================] - 31s 100ms/step - loss: 0.0072
# Epoch 13/50
# 316/316 [==============================] - 29s 91ms/step - loss: 0.0072
# Epoch 14/50
# 316/316 [==============================] - 34s 107ms/step - loss: 0.0071
# Epoch 15/50
# 316/316 [==============================] - 30s 96ms/step - loss: 0.0071
# Epoch 16/50
# 316/316 [==============================] - 30s 95ms/step - loss: 0.0071
# Epoch 17/50
# 316/316 [==============================] - 30s 94ms/step - loss: 0.0071
# Epoch 18/50
# 316/316 [==============================] - 33s 104ms/step - loss: 0.0071
# Epoch 19/50
# 316/316 [==============================] - 30s 96ms/step - loss: 0.0071
# Epoch 20/50
# 316/316 [==============================] - 32s 100ms/step - loss: 0.0071
# Epoch 21/50
# 316/316 [==============================] - 35s 110ms/step - loss: 0.0071
# Epoch 22/50
# 316/316 [==============================] - 36s 113ms/step - loss: 0.0071
# Epoch 23/50
# 316/316 [==============================] - 33s 105ms/step - loss: 0.0070
# Epoch 24/50
# 316/316 [==============================] - 31s 99ms/step - loss: 0.0070
# Epoch 25/50
# 316/316 [==============================] - 33s 105ms/step - loss: 0.0070
# Epoch 26/50
# 316/316 [==============================] - 32s 102ms/step - loss: 0.0070
# Epoch 27/50
# 316/316 [==============================] - 32s 102ms/step - loss: 0.0070
# Epoch 28/50
# 316/316 [==============================] - 31s 98ms/step - loss: 0.0070
# Epoch 29/50
# 316/316 [==============================] - 33s 106ms/step - loss: 0.0070
# Epoch 30/50
# 316/316 [==============================] - 29s 92ms/step - loss: 0.0070
# Epoch 31/50
# 316/316 [==============================] - 30s 96ms/step - loss: 0.0070
# Epoch 32/50
# 316/316 [==============================] - 33s 104ms/step - loss: 0.0070
# Epoch 33/50
# 316/316 [==============================] - 32s 102ms/step - loss: 0.0070
# Epoch 34/50
# 316/316 [==============================] - 31s 97ms/step - loss: 0.0070
# Epoch 35/50
# 316/316 [==============================] - 31s 98ms/step - loss: 0.0070
# Epoch 36/50
# 316/316 [==============================] - 32s 101ms/step - loss: 0.0069
# Epoch 37/50
# 316/316 [==============================] - 32s 101ms/step - loss: 0.0069
# Epoch 39/50
# 316/316 [==============================] - 32s 101ms/step - loss: 0.0069
# Epoch 41/50
# 316/316 [==============================] - 31s 98ms/step - loss: 0.0069
# Epoch 44/50
# 316/316 [==============================] - 31s 98ms/step - loss: 0.0069
# Epoch 45/50
# 316/316 [==============================] - 31s 97ms/step - loss: 0.0068
# Epoch 46/50
# 316/316 [==============================] - 32s 102ms/step - loss: 0.0068
# Epoch 49/50
# 316/316 [==============================] - 34s 107ms/step - loss: 0.0068
# Epoch 50/50
# 282/316 [=========================>....] - ETA: 3s - loss: 0.0068

# %%
# Escalar los datos de prueba
test_scaled = scaler.transform(test.values.reshape(-1, 1))

# Crear secuencias para el conjunto de prueba
X_test, y_test = create_sequences(test_scaled, time_step)

# Reshape de los datos de prueba
X_test_reshaped = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Realizar predicciones
predictions = model.predict(X_test_reshaped)

# Invertir la escala de las predicciones
predictions_inverted = scaler.inverse_transform(predictions)
y_test_inverted = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calcular el error cuadrático medio (MSE)
mse = np.mean((predictions_inverted - y_test_inverted) ** 2)
print(f'Error cuadrático medio (MSE): {mse}')
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 33, Finished, Available, Finished)
# 3/3 [==============================] - 1s 22ms/step
# Error cuadrático medio (MSE): 0.07546083158429114

# %%
# Guardamos el modelo: 
model.save('modelo_completo.h5')
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 34, Finished, Available, Finished)

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_inverted, label='Valores Reales')
plt.plot(predictions_inverted, label='Predicciones', color='red')
plt.title('Predicción con LSTM')
plt.xlabel('Tiempo')
plt.ylabel('Consumo Total')
plt.legend()
plt.show()
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 35, Finished, Available, Finished)

# %% [markdown]
# # Modelo VAR

# %%
df_datos_sensores.columns
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 46, Finished, Available, Finished)
# Index(['Fecha', 'Hora', 'Consumo_Total_kWhs', 'Refrigeradora',
#        'Tomacorrientes_Cocina', 'Cocina_Induccion',
#        'Tomacorriente_PB_y_Lavadora', 'Tomacorriente_PA',
#        'AireAcondicionado_Cuarto1', 'AireAcondicionado_Cuarto2',
#        'AireAcondicionado_Oficina', 'AireAcondicionado_Sala', 'Iluminacion_PB',
#        'Iluminacion_PA', 'Bomba_Agua', 'Balance',
#        'CuartoPrincipal_Temperatura_C', 'CuartoPrincipal_Humedad_Relativa_%',
#        'Sala_Temperatura_C', 'Sala_Humedad_Relativa_%', 'Cocina_Temperatura_C',
#        'Cocina_Humedad_Relativa_%', 'PatioLateral_Temperatura_C',
#        'PatioLateral_Humedad_Relativa_%', 'ExteriorFachada_Temperatura_C',
#        'ExteriorFachada_Humedad_Relativa_%'],
#       dtype='object')

# %%
datos_var = df_datos_sensores[['Fecha', 'Hora', 'Consumo_Total_kWhs', 'CuartoPrincipal_Temperatura_C', 
'CuartoPrincipal_Humedad_Relativa_%', 'Sala_Temperatura_C', 'Sala_Humedad_Relativa_%', 'Cocina_Temperatura_C',
'Cocina_Humedad_Relativa_%', 'PatioLateral_Temperatura_C','PatioLateral_Humedad_Relativa_%', 'ExteriorFachada_Temperatura_C',
       'ExteriorFachada_Humedad_Relativa_%' ]]


datos_var.dropna(inplace=True)

conteo_por_fecha  = datos_var.groupby('Fecha').size().reset_index(name='Repeticiones')
print(f"Porcentaje válido: {100*conteo_por_fecha[conteo_por_fecha['Repeticiones'] == 24].shape[0]/conteo_por_fecha.shape[0]}.")
print('Fechas a excluir:')
fechas_excluir = conteo_por_fecha[conteo_por_fecha['Repeticiones'] != 24]['Fecha']
fechas_excluir
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 47, Finished, Available, Finished)
# Porcentaje válido: 77.64227642276423.
# Fechas a excluir:
# /tmp/ipykernel_8399/2558794351.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_var.dropna(inplace=True)
# 0      2023-11-22
# 2      2023-11-24
# 5      2023-11-27
# 6      2023-11-28
# 7      2023-11-29
# 8      2023-11-30
# 13     2023-12-05
# 15     2023-12-07
# 16     2023-12-08
# 19     2023-12-11
# 21     2023-12-13
# 22     2023-12-14
# 23     2023-12-15
# 24     2023-12-16
# 62     2024-01-23
# 90     2024-02-20
# 104    2024-03-05
# 107    2024-03-08
# 114    2024-03-15
# 118    2024-03-19
# 125    2024-03-26
# 127    2024-03-28
# 134    2024-04-04
# 139    2024-04-09
# 144    2024-04-14
# 145    2024-04-15
# 146    2024-04-16
# 147    2024-04-17
# 148    2024-04-18
# 149    2024-04-19
# 150    2024-04-20
# 152    2024-04-22
# 153    2024-04-23
# 154    2024-04-24
# 155    2024-04-25
# 156    2024-04-26
# 157    2024-04-27
# 159    2024-04-29
# 160    2024-04-30
# 180    2024-05-20
# 186    2024-05-26
# 200    2024-06-09
# 202    2024-06-11
# 203    2024-06-12
# 205    2024-06-14
# 210    2024-06-19
# 212    2024-06-21
# 213    2024-06-22
# 214    2024-06-23
# 215    2024-07-27
# 222    2024-08-03
# 227    2024-08-08
# 231    2024-08-12
# 240    2024-08-21
# 245    2024-08-26
# Name: Fecha, dtype: object

# %%
datos_var_modelo= datos_var[~datos_var['Fecha'].isin(fechas_excluir)]
datos_var_modelo.loc[:, 'FechaHora']  = datos_var_modelo['Fecha'] + ' ' + datos_var_modelo['Hora']
datos_var_modelo.drop(['Fecha', 'Hora'], axis=1, inplace = True)
datos_var_modelo.head(5)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 48, Finished, Available, Finished)
# /tmp/ipykernel_8399/3606281620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_var_modelo.loc[:, 'FechaHora']  = datos_var_modelo['Fecha'] + ' ' + datos_var_modelo['Hora']
# /tmp/ipykernel_8399/3606281620.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_var_modelo.drop(['Fecha', 'Hora'], axis=1, inplace = True)
#       Consumo_Total_kWhs  CuartoPrincipal_Temperatura_C  \
# 3587              0.5218                           23.6
# 3588              0.4672                           23.6
# 3589              0.4103                           23.5
# 3590              0.4159                           23.2
# 3591              0.3379                           24.1
#
#       CuartoPrincipal_Humedad_Relativa_%  Sala_Temperatura_C  \
# 3587                                46.0                28.9
# 3588                                50.0                28.6
# 3589                                50.0                28.5
# 3590                                52.0                28.2
# 3591                                54.0                28.1
#
#       Sala_Humedad_Relativa_%  Cocina_Temperatura_C  \
# 3587                     62.0                  29.5
# 3588                     62.0                  29.4
# 3589                     62.0                  29.3
# 3590                     63.0                  29.1
# 3591                     63.0                  29.1
#
#       Cocina_Humedad_Relativa_%  PatioLateral_Temperatura_C  \
# 3587                       58.0                        24.9
# 3588                       58.0                        24.7
# 3589                       58.0                        25.0
# 3590                       58.0                        24.6
# 3591                       59.0                        24.8
#
#       PatioLateral_Humedad_Relativa_%  ExteriorFachada_Temperatura_C  \
# 3587                             76.0                           24.3
# 3588                             76.0                           24.2
# 3589                             73.0                           24.2
# 3590                             76.0                           24.0
# 3591                             75.0                           24.3
#
#       ExteriorFachada_Humedad_Relativa_%                    FechaHora
# 3587                                77.0  2023-11-23 00:00:00.0000000
# 3588                                77.0  2023-11-23 01:00:00.0000000
# 3589                                74.0  2023-11-23 02:00:00.0000000
# 3590                                77.0  2023-11-23 03:00:00.0000000
# 3591                                76.0  2023-11-23 04:00:00.0000000

# %%
def check_stationarity(series):
    result = adfuller(series)
    return result[1]  # Retorna el valor p

# Verificar estacionaridad y diferenciar si es necesario
differenced_data = datos_var_modelo[['Consumo_Total_kWhs', 'CuartoPrincipal_Temperatura_C',
       'CuartoPrincipal_Humedad_Relativa_%', 'Sala_Temperatura_C',
       'Sala_Humedad_Relativa_%', 'Cocina_Temperatura_C',
       'Cocina_Humedad_Relativa_%', 'PatioLateral_Temperatura_C',
       'PatioLateral_Humedad_Relativa_%', 'ExteriorFachada_Temperatura_C',
       'ExteriorFachada_Humedad_Relativa_%']]
for col in differenced_data.columns:
    p_value = check_stationarity(differenced_data[col])
    while p_value > 0.05:  # Si la serie no es estacionaria
        differenced_data[col] = differenced_data[col].diff().dropna()
        p_value = check_stationarity(differenced_data[col])
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 65, Finished, Available, Finished)

# %%
train_size = int(len(differenced_data) * 0.99)
train_data, test_data = differenced_data.iloc[:train_size], differenced_data.iloc[train_size:]
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 66, Finished, Available, Finished)

# %%
# Optimización del Orden del Modelo VAR
def optimize_var_lag(model, max_lags_list):
    best_aic = np.inf
    best_lag = 0
    best_model = None
    
    for max_lag in max_lags_list:
        result = model.select_order(maxlags=max_lag, trend='c')
        if result.aic < best_aic:
            best_aic = result.aic
            best_lag = result.aic
            best_model = model.fit(result.aic)
    
    return best_model, best_lag
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 67, Finished, Available, Finished)

# %%
from statsmodels.tsa.api import VAR

model = VAR(train_data)

# Optimizar el lag del modelo VAR
max_lags_list = [10, 15, 20, 25, 30]  # Ajustar el rango de maxlags según sea necesario
best_model, best_lag = optimize_var_lag(model, max_lags_list)

print(f"Lag óptimo seleccionado después de optimización: {best_lag}")
print(best_model.summary())
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 68, Finished, Available, Finished)
# /home/trusted-service-user/cluster-env/env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Lag óptimo seleccionado después de optimización: 10
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 09, Sep, 2024
# Time:                     04:18:31
# --------------------------------------------------------------------
# No. of Equations:         11.0000    BIC:                    1.59983
# Nobs:                     4528.00    HQIC:                  0.478795
# Log likelihood:          -69157.3    FPE:                   0.877462
# AIC:                    -0.130830    Det(Omega_mle):        0.672250
# --------------------------------------------------------------------
# Results for equation Consumo_Total_kWhs
# =========================================================================================================
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                         -0.335831         0.282223           -1.190           0.234
# L1.Consumo_Total_kWhs                          0.419109         0.017486           23.968           0.000
# L1.CuartoPrincipal_Temperatura_C              -0.000655         0.008366           -0.078           0.938
# L1.CuartoPrincipal_Humedad_Relativa_%         -0.001947         0.001798           -1.083           0.279
# L1.Sala_Temperatura_C                         -0.047600         0.017727           -2.685           0.007
# L1.Sala_Humedad_Relativa_%                    -0.017699         0.004870           -3.634           0.000
# L1.Cocina_Temperatura_C                       -0.008380         0.020705           -0.405           0.686
# L1.Cocina_Humedad_Relativa_%                  -0.000705         0.004184           -0.169           0.866
# L1.PatioLateral_Temperatura_C                  0.007956         0.009773            0.814           0.416
# L1.PatioLateral_Humedad_Relativa_%            -0.001826         0.002372           -0.770           0.441
# L1.ExteriorFachada_Temperatura_C               0.006260         0.011673            0.536           0.592
# L1.ExteriorFachada_Humedad_Relativa_%          0.005108         0.003406            1.500           0.134
# L2.Consumo_Total_kWhs                         -0.058071         0.018994           -3.057           0.002
# L2.CuartoPrincipal_Temperatura_C              -0.008804         0.010793           -0.816           0.415
# L2.CuartoPrincipal_Humedad_Relativa_%          0.003951         0.002084            1.896           0.058
# L2.Sala_Temperatura_C                          0.062005         0.020103            3.084           0.002
# L2.Sala_Humedad_Relativa_%                     0.007895         0.005199            1.518           0.129
# L2.Cocina_Temperatura_C                       -0.009507         0.026348           -0.361           0.718
# L2.Cocina_Humedad_Relativa_%                  -0.005263         0.004375           -1.203           0.229
# L2.PatioLateral_Temperatura_C                 -0.007806         0.012283           -0.636           0.525
# L2.PatioLateral_Humedad_Relativa_%            -0.001600         0.002801           -0.571           0.568
# L2.ExteriorFachada_Temperatura_C               0.039465         0.013892            2.841           0.005
# L2.ExteriorFachada_Humedad_Relativa_%          0.010345         0.003949            2.619           0.009
# L3.Consumo_Total_kWhs                          0.060488         0.019076            3.171           0.002
# L3.CuartoPrincipal_Temperatura_C               0.014772         0.010820            1.365           0.172
# L3.CuartoPrincipal_Humedad_Relativa_%         -0.000361         0.002089           -0.173           0.863
# L3.Sala_Temperatura_C                         -0.005598         0.020186           -0.277           0.782
# L3.Sala_Humedad_Relativa_%                     0.005006         0.005222            0.959           0.338
# L3.Cocina_Temperatura_C                       -0.025663         0.026511           -0.968           0.333
# L3.Cocina_Humedad_Relativa_%                  -0.000554         0.004399           -0.126           0.900
# L3.PatioLateral_Temperatura_C                  0.000090         0.012340            0.007           0.994
# L3.PatioLateral_Humedad_Relativa_%            -0.001662         0.002805           -0.593           0.553
# L3.ExteriorFachada_Temperatura_C              -0.031199         0.014088           -2.215           0.027
# L3.ExteriorFachada_Humedad_Relativa_%         -0.004365         0.003964           -1.101           0.271
# L4.Consumo_Total_kWhs                         -0.023487         0.019062           -1.232           0.218
# L4.CuartoPrincipal_Temperatura_C              -0.000602         0.010819           -0.056           0.956
# L4.CuartoPrincipal_Humedad_Relativa_%         -0.001241         0.002086           -0.595           0.552
# L4.Sala_Temperatura_C                         -0.022422         0.020231           -1.108           0.268
# L4.Sala_Humedad_Relativa_%                     0.000409         0.005224            0.078           0.938
# L4.Cocina_Temperatura_C                        0.034520         0.026549            1.300           0.194
# L4.Cocina_Humedad_Relativa_%                   0.004956         0.004400            1.126           0.260
# L4.PatioLateral_Temperatura_C                  0.003395         0.012328            0.275           0.783
# L4.PatioLateral_Humedad_Relativa_%             0.001890         0.002806            0.673           0.501
# L4.ExteriorFachada_Temperatura_C               0.007293         0.014080            0.518           0.604
# L4.ExteriorFachada_Humedad_Relativa_%         -0.002740         0.003963           -0.691           0.489
# L5.Consumo_Total_kWhs                         -0.002181         0.019070           -0.114           0.909
# L5.CuartoPrincipal_Temperatura_C              -0.021831         0.010809           -2.020           0.043
# L5.CuartoPrincipal_Humedad_Relativa_%          0.006901         0.002085            3.310           0.001
# L5.Sala_Temperatura_C                         -0.002737         0.020228           -0.135           0.892
# L5.Sala_Humedad_Relativa_%                     0.001515         0.005225            0.290           0.772
# L5.Cocina_Temperatura_C                        0.009416         0.026501            0.355           0.722
# L5.Cocina_Humedad_Relativa_%                  -0.002879         0.004400           -0.654           0.513
# L5.PatioLateral_Temperatura_C                 -0.017999         0.012260           -1.468           0.142
# L5.PatioLateral_Humedad_Relativa_%             0.000689         0.002795            0.247           0.805
# L5.ExteriorFachada_Temperatura_C              -0.004970         0.014084           -0.353           0.724
# L5.ExteriorFachada_Humedad_Relativa_%         -0.004440         0.003966           -1.119           0.263
# L6.Consumo_Total_kWhs                         -0.048401         0.019065           -2.539           0.011
# L6.CuartoPrincipal_Temperatura_C               0.020765         0.010819            1.919           0.055
# L6.CuartoPrincipal_Humedad_Relativa_%         -0.004776         0.002085           -2.291           0.022
# L6.Sala_Temperatura_C                         -0.041731         0.020207           -2.065           0.039
# L6.Sala_Humedad_Relativa_%                    -0.002311         0.005224           -0.442           0.658
# L6.Cocina_Temperatura_C                        0.019872         0.026477            0.751           0.453
# L6.Cocina_Humedad_Relativa_%                   0.000314         0.004400            0.071           0.943
# L6.PatioLateral_Temperatura_C                 -0.011582         0.012250           -0.946           0.344
# L6.PatioLateral_Humedad_Relativa_%            -0.003718         0.002788           -1.334           0.182
# L6.ExteriorFachada_Temperatura_C               0.010530         0.014100            0.747           0.455
# L6.ExteriorFachada_Humedad_Relativa_%          0.004785         0.003963            1.207           0.227
# L7.Consumo_Total_kWhs                         -0.030493         0.019077           -1.598           0.110
# L7.CuartoPrincipal_Temperatura_C              -0.024394         0.010825           -2.254           0.024
# L7.CuartoPrincipal_Humedad_Relativa_%          0.000688         0.002085            0.330           0.741
# L7.Sala_Temperatura_C                          0.004151         0.020219            0.205           0.837
# L7.Sala_Humedad_Relativa_%                     0.016388         0.005230            3.133           0.002
# L7.Cocina_Temperatura_C                        0.009886         0.026464            0.374           0.709
# L7.Cocina_Humedad_Relativa_%                  -0.009977         0.004402           -2.266           0.023
# L7.PatioLateral_Temperatura_C                  0.015978         0.012287            1.300           0.193
# L7.PatioLateral_Humedad_Relativa_%             0.003547         0.002794            1.270           0.204
# L7.ExteriorFachada_Temperatura_C               0.025553         0.014110            1.811           0.070
# L7.ExteriorFachada_Humedad_Relativa_%         -0.003496         0.003962           -0.883           0.377
# L8.Consumo_Total_kWhs                          0.002713         0.019059            0.142           0.887
# L8.CuartoPrincipal_Temperatura_C               0.000161         0.010809            0.015           0.988
# L8.CuartoPrincipal_Humedad_Relativa_%         -0.000916         0.002085           -0.439           0.660
# L8.Sala_Temperatura_C                          0.021712         0.020202            1.075           0.283
# L8.Sala_Humedad_Relativa_%                    -0.004416         0.005240           -0.843           0.399
# L8.Cocina_Temperatura_C                       -0.012181         0.026461           -0.460           0.645
# L8.Cocina_Humedad_Relativa_%                  -0.002827         0.004410           -0.641           0.522
# L8.PatioLateral_Temperatura_C                 -0.014297         0.012235           -1.168           0.243
# L8.PatioLateral_Humedad_Relativa_%            -0.003907         0.002793           -1.399           0.162
# L8.ExteriorFachada_Temperatura_C               0.013395         0.014067            0.952           0.341
# L8.ExteriorFachada_Humedad_Relativa_%          0.003354         0.003965            0.846           0.398
# L9.Consumo_Total_kWhs                         -0.002609         0.018971           -0.138           0.891
# L9.CuartoPrincipal_Temperatura_C              -0.011995         0.010666           -1.125           0.261
# L9.CuartoPrincipal_Humedad_Relativa_%          0.001832         0.002059            0.890           0.374
# L9.Sala_Temperatura_C                         -0.011663         0.020041           -0.582           0.561
# L9.Sala_Humedad_Relativa_%                     0.004278         0.005212            0.821           0.412
# L9.Cocina_Temperatura_C                        0.006080         0.026068            0.233           0.816
# L9.Cocina_Humedad_Relativa_%                  -0.002520         0.004383           -0.575           0.565
# L9.PatioLateral_Temperatura_C                  0.006892         0.012170            0.566           0.571
# L9.PatioLateral_Humedad_Relativa_%            -0.001219         0.002789           -0.437           0.662
# L9.ExteriorFachada_Temperatura_C               0.014974         0.014069            1.064           0.287
# L9.ExteriorFachada_Humedad_Relativa_%          0.009865         0.003930            2.510           0.012
# L10.Consumo_Total_kWhs                         0.008964         0.017654            0.508           0.612
# L10.CuartoPrincipal_Temperatura_C              0.007618         0.007582            1.005           0.315
# L10.CuartoPrincipal_Humedad_Relativa_%        -0.002353         0.001593           -1.478           0.140
# L10.Sala_Temperatura_C                         0.031639         0.017892            1.768           0.077
# L10.Sala_Humedad_Relativa_%                   -0.002782         0.004557           -0.611           0.541
# L10.Cocina_Temperatura_C                      -0.029933         0.021288           -1.406           0.160
# L10.Cocina_Humedad_Relativa_%                 -0.002195         0.004246           -0.517           0.605
# L10.PatioLateral_Temperatura_C                -0.003498         0.009911           -0.353           0.724
# L10.PatioLateral_Humedad_Relativa_%            0.001834         0.002270            0.808           0.419
# L10.ExteriorFachada_Temperatura_C              0.006299         0.011993            0.525           0.599
# L10.ExteriorFachada_Humedad_Relativa_%        -0.001499         0.003373           -0.444           0.657
# =========================================================================================================
#
# Results for equation CuartoPrincipal_Temperatura_C
# =========================================================================================================
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                          8.543756         0.910639            9.382           0.000
# L1.Consumo_Total_kWhs                         -0.100807         0.056422           -1.787           0.074
# L1.CuartoPrincipal_Temperatura_C               0.771288         0.026996           28.571           0.000
# L1.CuartoPrincipal_Humedad_Relativa_%          0.025982         0.005801            4.479           0.000
# L1.Sala_Temperatura_C                          0.002305         0.057200            0.040           0.968
# L1.Sala_Humedad_Relativa_%                    -0.004146         0.015715           -0.264           0.792
# L1.Cocina_Temperatura_C                       -0.187749         0.066809           -2.810           0.005
# L1.Cocina_Humedad_Relativa_%                   0.013164         0.013502            0.975           0.330
# L1.PatioLateral_Temperatura_C                  0.099096         0.031535            3.142           0.002
# L1.PatioLateral_Humedad_Relativa_%            -0.011149         0.007655           -1.457           0.145
# L1.ExteriorFachada_Temperatura_C               0.199070         0.037665            5.285           0.000
# L1.ExteriorFachada_Humedad_Relativa_%          0.003144         0.010990            0.286           0.775
# L2.Consumo_Total_kWhs                          0.060828         0.061287            0.993           0.321
# L2.CuartoPrincipal_Temperatura_C              -0.107773         0.034826           -3.095           0.002
# L2.CuartoPrincipal_Humedad_Relativa_%         -0.017546         0.006723           -2.610           0.009
# L2.Sala_Temperatura_C                          0.026795         0.064865            0.413           0.680
# L2.Sala_Humedad_Relativa_%                     0.019676         0.016776            1.173           0.241
# L2.Cocina_Temperatura_C                        0.046835         0.085015            0.551           0.582
# L2.Cocina_Humedad_Relativa_%                  -0.017658         0.014115           -1.251           0.211
# L2.PatioLateral_Temperatura_C                 -0.021511         0.039634           -0.543           0.587
# L2.PatioLateral_Humedad_Relativa_%             0.020257         0.009039            2.241           0.025
# L2.ExteriorFachada_Temperatura_C              -0.087511         0.044826           -1.952           0.051
# L2.ExteriorFachada_Humedad_Relativa_%         -0.016126         0.012744           -1.265           0.206
# L3.Consumo_Total_kWhs                          0.003010         0.061553            0.049           0.961
# L3.CuartoPrincipal_Temperatura_C               0.012702         0.034911            0.364           0.716
# L3.CuartoPrincipal_Humedad_Relativa_%         -0.007066         0.006740           -1.048           0.295
# L3.Sala_Temperatura_C                          0.173369         0.065133            2.662           0.008
# L3.Sala_Humedad_Relativa_%                    -0.052990         0.016850           -3.145           0.002
# L3.Cocina_Temperatura_C                       -0.070838         0.085541           -0.828           0.408
# L3.Cocina_Humedad_Relativa_%                  -0.004658         0.014194           -0.328           0.743
# L3.PatioLateral_Temperatura_C                 -0.042152         0.039818           -1.059           0.290
# L3.PatioLateral_Humedad_Relativa_%            -0.004873         0.009050           -0.538           0.590
# L3.ExteriorFachada_Temperatura_C               0.016808         0.045458            0.370           0.712
# L3.ExteriorFachada_Humedad_Relativa_%          0.004090         0.012790            0.320           0.749
# L4.Consumo_Total_kWhs                         -0.023180         0.061506           -0.377           0.706
# L4.CuartoPrincipal_Temperatura_C               0.001796         0.034908            0.051           0.959
# L4.CuartoPrincipal_Humedad_Relativa_%         -0.002671         0.006732           -0.397           0.692
# L4.Sala_Temperatura_C                         -0.023192         0.065280           -0.355           0.722
# L4.Sala_Humedad_Relativa_%                     0.033348         0.016856            1.978           0.048
# L4.Cocina_Temperatura_C                        0.056923         0.085663            0.664           0.506
# L4.Cocina_Humedad_Relativa_%                  -0.024140         0.014196           -1.700           0.089
# L4.PatioLateral_Temperatura_C                  0.029483         0.039779            0.741           0.459
# L4.PatioLateral_Humedad_Relativa_%             0.003358         0.009054            0.371           0.711
# L4.ExteriorFachada_Temperatura_C               0.040768         0.045430            0.897           0.370
# L4.ExteriorFachada_Humedad_Relativa_%          0.004178         0.012786            0.327           0.744
# L5.Consumo_Total_kWhs                          0.045229         0.061533            0.735           0.462
# L5.CuartoPrincipal_Temperatura_C               0.018312         0.034878            0.525           0.600
# L5.CuartoPrincipal_Humedad_Relativa_%         -0.009909         0.006726           -1.473           0.141
# L5.Sala_Temperatura_C                         -0.054194         0.065270           -0.830           0.406
# L5.Sala_Humedad_Relativa_%                    -0.022450         0.016860           -1.332           0.183
# L5.Cocina_Temperatura_C                        0.097725         0.085511            1.143           0.253
# L5.Cocina_Humedad_Relativa_%                   0.009136         0.014197            0.644           0.520
# L5.PatioLateral_Temperatura_C                 -0.004372         0.039558           -0.111           0.912
# L5.PatioLateral_Humedad_Relativa_%            -0.000771         0.009017           -0.085           0.932
# L5.ExteriorFachada_Temperatura_C              -0.006981         0.045445           -0.154           0.878
# L5.ExteriorFachada_Humedad_Relativa_%          0.001726         0.012798            0.135           0.893
# L6.Consumo_Total_kWhs                         -0.009534         0.061517           -0.155           0.877
# L6.CuartoPrincipal_Temperatura_C              -0.011168         0.034909           -0.320           0.749
# L6.CuartoPrincipal_Humedad_Relativa_%          0.006496         0.006728            0.965           0.334
# L6.Sala_Temperatura_C                          0.075233         0.065203            1.154           0.249
# L6.Sala_Humedad_Relativa_%                     0.022766         0.016856            1.351           0.177
# L6.Cocina_Temperatura_C                       -0.104109         0.085432           -1.219           0.223
# L6.Cocina_Humedad_Relativa_%                  -0.020292         0.014196           -1.429           0.153
# L6.PatioLateral_Temperatura_C                 -0.005539         0.039525           -0.140           0.889
# L6.PatioLateral_Humedad_Relativa_%             0.002803         0.008997            0.312           0.755
# L6.ExteriorFachada_Temperatura_C               0.026184         0.045497            0.576           0.565
# L6.ExteriorFachada_Humedad_Relativa_%          0.024383         0.012789            1.907           0.057
# L7.Consumo_Total_kWhs                         -0.036142         0.061555           -0.587           0.557
# L7.CuartoPrincipal_Temperatura_C               0.013636         0.034927            0.390           0.696
# L7.CuartoPrincipal_Humedad_Relativa_%          0.000227         0.006729            0.034           0.973
# L7.Sala_Temperatura_C                          0.019916         0.065242            0.305           0.760
# L7.Sala_Humedad_Relativa_%                    -0.045079         0.016877           -2.671           0.008
# L7.Cocina_Temperatura_C                        0.040517         0.085391            0.474           0.635
# L7.Cocina_Humedad_Relativa_%                   0.031177         0.014205            2.195           0.028
# L7.PatioLateral_Temperatura_C                 -0.046802         0.039647           -1.180           0.238
# L7.PatioLateral_Humedad_Relativa_%            -0.020849         0.009014           -2.313           0.021
# L7.ExteriorFachada_Temperatura_C               0.048391         0.045529            1.063           0.288
# L7.ExteriorFachada_Humedad_Relativa_%          0.044054         0.012782            3.446           0.001
# L8.Consumo_Total_kWhs                          0.039427         0.061496            0.641           0.521
# L8.CuartoPrincipal_Temperatura_C              -0.005255         0.034878           -0.151           0.880
# L8.CuartoPrincipal_Humedad_Relativa_%         -0.006978         0.006727           -1.037           0.300
# L8.Sala_Temperatura_C                          0.033057         0.065187            0.507           0.612
# L8.Sala_Humedad_Relativa_%                    -0.008193         0.016907           -0.485           0.628
# L8.Cocina_Temperatura_C                       -0.146576         0.085380           -1.717           0.086
# L8.Cocina_Humedad_Relativa_%                  -0.004809         0.014230           -0.338           0.735
# L8.PatioLateral_Temperatura_C                 -0.004575         0.039480           -0.116           0.908
# L8.PatioLateral_Humedad_Relativa_%             0.005304         0.009013            0.588           0.556
# L8.ExteriorFachada_Temperatura_C               0.072650         0.045391            1.601           0.109
# L8.ExteriorFachada_Humedad_Relativa_%          0.002905         0.012795            0.227           0.820
# L9.Consumo_Total_kWhs                         -0.033778         0.061213           -0.552           0.581
# L9.CuartoPrincipal_Temperatura_C               0.016504         0.034417            0.480           0.632
# L9.CuartoPrincipal_Humedad_Relativa_%         -0.014824         0.006644           -2.231           0.026
# L9.Sala_Temperatura_C                          0.023947         0.064667            0.370           0.711
# L9.Sala_Humedad_Relativa_%                    -0.002624         0.016818           -0.156           0.876
# L9.Cocina_Temperatura_C                        0.009888         0.084112            0.118           0.906
# L9.Cocina_Humedad_Relativa_%                   0.008370         0.014141            0.592           0.554
# L9.PatioLateral_Temperatura_C                 -0.000448         0.039269           -0.011           0.991
# L9.PatioLateral_Humedad_Relativa_%             0.009332         0.008998            1.037           0.300
# L9.ExteriorFachada_Temperatura_C               0.005235         0.045396            0.115           0.908
# L9.ExteriorFachada_Humedad_Relativa_%         -0.001738         0.012681           -0.137           0.891
# L10.Consumo_Total_kWhs                        -0.201792         0.056964           -3.542           0.000
# L10.CuartoPrincipal_Temperatura_C             -0.007351         0.024464           -0.300           0.764
# L10.CuartoPrincipal_Humedad_Relativa_%         0.001948         0.005139            0.379           0.705
# L10.Sala_Temperatura_C                        -0.133027         0.057730           -2.304           0.021
# L10.Sala_Humedad_Relativa_%                    0.007283         0.014704            0.495           0.620
# L10.Cocina_Temperatura_C                       0.013463         0.068689            0.196           0.845
# L10.Cocina_Humedad_Relativa_%                  0.012134         0.013701            0.886           0.376
# L10.PatioLateral_Temperatura_C                -0.055371         0.031981           -1.731           0.083
# L10.PatioLateral_Humedad_Relativa_%           -0.012052         0.007325           -1.645           0.100
# L10.ExteriorFachada_Temperatura_C             -0.107402         0.038699           -2.775           0.006
# L10.ExteriorFachada_Humedad_Relativa_%        -0.015819         0.010884           -1.453           0.146
# =========================================================================================================
#
# Results for equation CuartoPrincipal_Humedad_Relativa_%
# =========================================================================================================
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                         33.704177         4.086666            8.247           0.000
# L1.Consumo_Total_kWhs                         -1.012191         0.253205           -3.998           0.000
# L1.CuartoPrincipal_Temperatura_C              -0.378954         0.121148           -3.128           0.002
# L1.CuartoPrincipal_Humedad_Relativa_%          0.667286         0.026034           25.631           0.000
# L1.Sala_Temperatura_C                         -0.780456         0.256697           -3.040           0.002
# L1.Sala_Humedad_Relativa_%                    -0.021484         0.070522           -0.305           0.761
# L1.Cocina_Temperatura_C                       -0.395012         0.299816           -1.318           0.188
# L1.Cocina_Humedad_Relativa_%                   0.219035         0.060592            3.615           0.000
# L1.PatioLateral_Temperatura_C                  0.075720         0.141519            0.535           0.593
# L1.PatioLateral_Humedad_Relativa_%             0.037441         0.034352            1.090           0.276
# L1.ExteriorFachada_Temperatura_C              -0.119572         0.169031           -0.707           0.479
# L1.ExteriorFachada_Humedad_Relativa_%         -0.057587         0.049321           -1.168           0.243
# L2.Consumo_Total_kWhs                          0.000762         0.275036            0.003           0.998
# L2.CuartoPrincipal_Temperatura_C              -0.323611         0.156289           -2.071           0.038
# L2.CuartoPrincipal_Humedad_Relativa_%          0.034236         0.030172            1.135           0.257
# L2.Sala_Temperatura_C                          0.593956         0.291093            2.040           0.041
# L2.Sala_Humedad_Relativa_%                     0.037438         0.075284            0.497           0.619
# L2.Cocina_Temperatura_C                        0.213004         0.381523            0.558           0.577
# L2.Cocina_Humedad_Relativa_%                  -0.202770         0.063345           -3.201           0.001
# L2.PatioLateral_Temperatura_C                 -0.007434         0.177865           -0.042           0.967
# L2.PatioLateral_Humedad_Relativa_%             0.058770         0.040564            1.449           0.147
# L2.ExteriorFachada_Temperatura_C              -0.174834         0.201165           -0.869           0.385
# L2.ExteriorFachada_Humedad_Relativa_%         -0.034019         0.057189           -0.595           0.552
# L3.Consumo_Total_kWhs                          0.054877         0.276229            0.199           0.843
# L3.CuartoPrincipal_Temperatura_C               0.083958         0.156671            0.536           0.592
# L3.CuartoPrincipal_Humedad_Relativa_%         -0.016254         0.030248           -0.537           0.591
# L3.Sala_Temperatura_C                          0.677353         0.292294            2.317           0.020
# L3.Sala_Humedad_Relativa_%                    -0.183825         0.075615           -2.431           0.015
# L3.Cocina_Temperatura_C                       -0.589450         0.383883           -1.535           0.125
# L3.Cocina_Humedad_Relativa_%                  -0.004414         0.063697           -0.069           0.945
# L3.PatioLateral_Temperatura_C                  0.118012         0.178690            0.660           0.509
# L3.PatioLateral_Humedad_Relativa_%            -0.006309         0.040615           -0.155           0.877
# L3.ExteriorFachada_Temperatura_C               0.106726         0.204000            0.523           0.601
# L3.ExteriorFachada_Humedad_Relativa_%          0.031396         0.057395            0.547           0.584
# L4.Consumo_Total_kWhs                         -0.199304         0.276018           -0.722           0.470
# L4.CuartoPrincipal_Temperatura_C               0.022782         0.156655            0.145           0.884
# L4.CuartoPrincipal_Humedad_Relativa_%         -0.003281         0.030209           -0.109           0.914
# L4.Sala_Temperatura_C                         -0.046219         0.292957           -0.158           0.875
# L4.Sala_Humedad_Relativa_%                     0.195734         0.075642            2.588           0.010
# L4.Cocina_Temperatura_C                        0.374497         0.384431            0.974           0.330
# L4.Cocina_Humedad_Relativa_%                  -0.216452         0.063708           -3.398           0.001
# L4.PatioLateral_Temperatura_C                  0.012119         0.178515            0.068           0.946
# L4.PatioLateral_Humedad_Relativa_%             0.007529         0.040632            0.185           0.853
# L4.ExteriorFachada_Temperatura_C               0.148376         0.203876            0.728           0.467
# L4.ExteriorFachada_Humedad_Relativa_%          0.048910         0.057380            0.852           0.394
# L5.Consumo_Total_kWhs                          0.287768         0.276141            1.042           0.297
# L5.CuartoPrincipal_Temperatura_C               0.196856         0.156522            1.258           0.209
# L5.CuartoPrincipal_Humedad_Relativa_%         -0.056036         0.030186           -1.856           0.063
# L5.Sala_Temperatura_C                         -0.327109         0.292912           -1.117           0.264
# L5.Sala_Humedad_Relativa_%                    -0.122782         0.075661           -1.623           0.105
# L5.Cocina_Temperatura_C                        0.075658         0.383745            0.197           0.844
# L5.Cocina_Humedad_Relativa_%                   0.121716         0.063714            1.910           0.056
# L5.PatioLateral_Temperatura_C                  0.092376         0.177525            0.520           0.603
# L5.PatioLateral_Humedad_Relativa_%             0.004595         0.040467            0.114           0.910
# L5.ExteriorFachada_Temperatura_C               0.109020         0.203944            0.535           0.593
# L5.ExteriorFachada_Humedad_Relativa_%          0.055322         0.057434            0.963           0.335
# L6.Consumo_Total_kWhs                         -0.230035         0.276069           -0.833           0.405
# L6.CuartoPrincipal_Temperatura_C              -0.027978         0.156659           -0.179           0.858
# L6.CuartoPrincipal_Humedad_Relativa_%          0.018244         0.030195            0.604           0.546
# L6.Sala_Temperatura_C                          0.324472         0.292610            1.109           0.267
# L6.Sala_Humedad_Relativa_%                     0.108255         0.075644            1.431           0.152
# L6.Cocina_Temperatura_C                       -0.582039         0.383390           -1.518           0.129
# L6.Cocina_Humedad_Relativa_%                  -0.026670         0.063709           -0.419           0.675
# L6.PatioLateral_Temperatura_C                  0.113961         0.177376            0.642           0.521
# L6.PatioLateral_Humedad_Relativa_%            -0.001909         0.040375           -0.047           0.962
# L6.ExteriorFachada_Temperatura_C              -0.043474         0.204177           -0.213           0.831
# L6.ExteriorFachada_Humedad_Relativa_%          0.030320         0.057391            0.528           0.597
# L7.Consumo_Total_kWhs                          0.065558         0.276240            0.237           0.812
# L7.CuartoPrincipal_Temperatura_C              -0.082420         0.156743           -0.526           0.599
# L7.CuartoPrincipal_Humedad_Relativa_%          0.012322         0.030197            0.408           0.683
# L7.Sala_Temperatura_C                          0.146554         0.292784            0.501           0.617
# L7.Sala_Humedad_Relativa_%                    -0.153516         0.075737           -2.027           0.043
# L7.Cocina_Temperatura_C                        0.619460         0.383208            1.617           0.106
# L7.Cocina_Humedad_Relativa_%                   0.108952         0.063749            1.709           0.087
# L7.PatioLateral_Temperatura_C                 -0.293604         0.177922           -1.650           0.099
# L7.PatioLateral_Humedad_Relativa_%            -0.068604         0.040452           -1.696           0.090
# L7.ExteriorFachada_Temperatura_C               0.209376         0.204318            1.025           0.305
# L7.ExteriorFachada_Humedad_Relativa_%          0.170505         0.057364            2.972           0.003
# L8.Consumo_Total_kWhs                          0.402267         0.275976            1.458           0.145
# L8.CuartoPrincipal_Temperatura_C               0.068215         0.156522            0.436           0.663
# L8.CuartoPrincipal_Humedad_Relativa_%         -0.019820         0.030187           -0.657           0.511
# L8.Sala_Temperatura_C                         -0.035272         0.292538           -0.121           0.904
# L8.Sala_Humedad_Relativa_%                    -0.042473         0.075874           -0.560           0.576
# L8.Cocina_Temperatura_C                       -0.476867         0.383160           -1.245           0.213
# L8.Cocina_Humedad_Relativa_%                  -0.038437         0.063858           -0.602           0.547
# L8.PatioLateral_Temperatura_C                 -0.064549         0.177174           -0.364           0.716
# L8.PatioLateral_Humedad_Relativa_%             0.017516         0.040450            0.433           0.665
# L8.ExteriorFachada_Temperatura_C               0.582948         0.203699            2.862           0.004
# L8.ExteriorFachada_Humedad_Relativa_%          0.077050         0.057421            1.342           0.180
# L9.Consumo_Total_kWhs                         -0.327788         0.274705           -1.193           0.233
# L9.CuartoPrincipal_Temperatura_C              -0.217786         0.154452           -1.410           0.159
# L9.CuartoPrincipal_Humedad_Relativa_%         -0.020765         0.029817           -0.696           0.486
# L9.Sala_Temperatura_C                         -0.047002         0.290204           -0.162           0.871
# L9.Sala_Humedad_Relativa_%                     0.034424         0.075472            0.456           0.648
# L9.Cocina_Temperatura_C                        0.185037         0.377469            0.490           0.624
# L9.Cocina_Humedad_Relativa_%                   0.002917         0.063461            0.046           0.963
# L9.PatioLateral_Temperatura_C                  0.016249         0.176226            0.092           0.927
# L9.PatioLateral_Humedad_Relativa_%            -0.006202         0.040382           -0.154           0.878
# L9.ExteriorFachada_Temperatura_C               0.044089         0.203721            0.216           0.829
# L9.ExteriorFachada_Humedad_Relativa_%          0.007759         0.056907            0.136           0.892
# L10.Consumo_Total_kWhs                        -0.739195         0.255639           -2.892           0.004
# L10.CuartoPrincipal_Temperatura_C             -0.073111         0.109786           -0.666           0.505
# L10.CuartoPrincipal_Humedad_Relativa_%         0.044005         0.023063            1.908           0.056
# L10.Sala_Temperatura_C                        -0.477851         0.259076           -1.844           0.065
# L10.Sala_Humedad_Relativa_%                   -0.011350         0.065987           -0.172           0.863
# L10.Cocina_Temperatura_C                      -0.124360         0.308254           -0.403           0.687
# L10.Cocina_Humedad_Relativa_%                  0.047560         0.061485            0.774           0.439
# L10.PatioLateral_Temperatura_C                -0.170184         0.143521           -1.186           0.236
# L10.PatioLateral_Humedad_Relativa_%           -0.026321         0.032873           -0.801           0.423
# L10.ExteriorFachada_Temperatura_C             -0.279790         0.173667           -1.611           0.107
# L10.ExteriorFachada_Humedad_Relativa_%        -0.017598         0.048845           -0.360           0.719
# =========================================================================================================
#
# Results for equation Sala_Temperatura_C
# =========================================================================================================
#                                             coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------
# const                                          1.281171         0.470467            2.723           0.006
# L1.Consumo_Total_kWhs                          0.007954         0.029149            0.273           0.785
# L1.CuartoPrincipal_Temperatura_C              -0.027393         0.013947           -1.964           0.050
# L1.CuartoPrincipal_Humedad_Relativa_%         -0.000718         0.002997           -0.240           0.811
# L1.Sala_Temperatura_C                          0.647256         0.029552           21.903           0.000
# L1.Sala_Humedad_Relativa_%                    -0.047047         0.008119           -5.795           0.000
# L1.Cocina_Temperatura_C                        0.215212         0.034515            6.235           0.000
# L1.Cocina_Humedad_Relativa_%                   0.059596         0.006975            8.544           0.000
# L1.PatioLateral_Temperatura_C                  0.068818         0.016292            4.224           0.000
# L1.PatioLateral_Humedad_Relativa_%             0.002936         0.003955            0.742           0.458
# L1.ExteriorFachada_Temperatura_C               0.049098         0.019459            2.523           0.012
# L1.ExteriorFachada_Humedad_Relativa_%         -0.011619         0.005678           -2.046           0.041
# L2.Consumo_Total_kWhs                          0.143312         0.031663            4.526           0.000
# L2.CuartoPrincipal_Temperatura_C               0.052805         0.017992            2.935           0.003
# L2.CuartoPrincipal_Humedad_Relativa_%         -0.003316         0.003474           -0.955           0.340
# L2.Sala_Temperatura_C                         -0.031552         0.033511           -0.942           0.346
# L2.Sala_Humedad_Relativa_%                     0.012655         0.008667            1.460           0.144
# L2.Cocina_Temperatura_C                       -0.058740         0.043922           -1.337           0.181
# L2.Cocina_Humedad_Relativa_%                  -0.007517         0.007292           -1.031           0.303
# L2.PatioLateral_Temperatura_C                  0.008694         0.020476            0.425           0.671
# L2.PatioLateral_Humedad_Relativa_%             0.008695         0.004670            1.862           0.063
# L2.ExteriorFachada_Temperatura_C              -0.064499         0.023159           -2.785           0.005
# L2.ExteriorFachada_Humedad_Relativa_%         -0.013568         0.006584           -2.061           0.039
# L3.Consumo_Total_kWhs                          0.030796         0.031800            0.968           0.333
# L3.CuartoPrincipal_Temperatura_C              -0.006017         0.018036           -0.334           0.739
# L3.CuartoPrincipal_Humedad_Relativa_%          0.000680         0.003482            0.195           0.845
# L3.Sala_Temperatura_C                          0.036266         0.033650            1.078           0.281
# L3.Sala_Humedad_Relativa_%                     0.003274         0.008705            0.376           0.707
# L3.Cocina_Temperatura_C                       -0.022914         0.044194           -0.518           0.604
# L3.Cocina_Humedad_Relativa_%                  -0.007746         0.007333           -1.056           0.291
# L3.PatioLateral_Temperatura_C                 -0.017562         0.020571           -0.854           0.393
# L3.PatioLateral_Humedad_Relativa_%            -0.008223         0.004676           -1.759           0.079
# L3.ExteriorFachada_Temperatura_C               0.012252         0.023485            0.522           0.602
# L3.ExteriorFachada_Humedad_Relativa_%          0.009920         0.006607            1.501           0.133
# L4.Consumo_Total_kWhs                          0.098124         0.031776            3.088           0.002
# L4.CuartoPrincipal_Temperatura_C              -0.013206         0.018035           -0.732           0.464
# L4.CuartoPrincipal_Humedad_Relativa_%          0.003927         0.003478            1.129           0.259
# L4.Sala_Temperatura_C                          0.078905         0.033726            2.340           0.019
# L4.Sala_Humedad_Relativa_%                     0.010516         0.008708            1.208           0.227
# L4.Cocina_Temperatura_C                       -0.043401         0.044257           -0.981           0.327
# L4.Cocina_Humedad_Relativa_%                  -0.010272         0.007334           -1.401           0.161
# L4.PatioLateral_Temperatura_C                 -0.032464         0.020551           -1.580           0.114
# L4.PatioLateral_Humedad_Relativa_%            -0.002382         0.004678           -0.509           0.611
# L4.ExteriorFachada_Temperatura_C               0.003670         0.023471            0.156           0.876
# L4.ExteriorFachada_Humedad_Relativa_%         -0.005276         0.006606           -0.799           0.424
# L5.Consumo_Total_kWhs                          0.022294         0.031790            0.701           0.483
# L5.CuartoPrincipal_Temperatura_C               0.014047         0.018019            0.780           0.436
# L5.CuartoPrincipal_Humedad_Relativa_%         -0.001800         0.003475           -0.518           0.605
# L5.Sala_Temperatura_C                          0.071862         0.033721            2.131           0.033
# L5.Sala_Humedad_Relativa_%                    -0.007873         0.008710           -0.904           0.366
# L5.Cocina_Temperatura_C                       -0.037927         0.044178           -0.859           0.391
# L5.Cocina_Humedad_Relativa_%                  -0.002191         0.007335           -0.299           0.765
# L5.PatioLateral_Temperatura_C                  0.031342         0.020437            1.534           0.125
# L5.PatioLateral_Humedad_Relativa_%             0.005141         0.004659            1.103           0.270
# L5.ExteriorFachada_Temperatura_C              -0.032811         0.023479           -1.398           0.162
# L5.ExteriorFachada_Humedad_Relativa_%         -0.002086         0.006612           -0.315           0.752
# L6.Consumo_Total_kWhs                         -0.016049         0.031782           -0.505           0.614
# L6.CuartoPrincipal_Temperatura_C              -0.018625         0.018035           -1.033           0.302
# L6.CuartoPrincipal_Humedad_Relativa_%          0.000405         0.003476            0.117           0.907
# L6.Sala_Temperatura_C                         -0.008733         0.033686           -0.259           0.795
# L6.Sala_Humedad_Relativa_%                     0.011301         0.008708            1.298           0.194
# L6.Cocina_Temperatura_C                        0.025723         0.044137            0.583           0.560
# L6.Cocina_Humedad_Relativa_%                   0.001363         0.007334            0.186           0.853
# L6.PatioLateral_Temperatura_C                 -0.017179         0.020420           -0.841           0.400
# L6.PatioLateral_Humedad_Relativa_%            -0.006023         0.004648           -1.296           0.195
# L6.ExteriorFachada_Temperatura_C               0.027876         0.023505            1.186           0.236
# L6.ExteriorFachada_Humedad_Relativa_%          0.005488         0.006607            0.831           0.406
# L7.Consumo_Total_kWhs                         -0.014710         0.031801           -0.463           0.644
# L7.CuartoPrincipal_Temperatura_C               0.017551         0.018045            0.973           0.331
# L7.CuartoPrincipal_Humedad_Relativa_%         -0.004126         0.003476           -1.187           0.235
# L7.Sala_Temperatura_C                         -0.007505         0.033706           -0.223           0.824
# L7.Sala_Humedad_Relativa_%                     0.000052         0.008719            0.006           0.995
# L7.Cocina_Temperatura_C                       -0.067295         0.044116           -1.525           0.127
# L7.Cocina_Humedad_Relativa_%                  -0.014974         0.007339           -2.040           0.041
# L7.PatioLateral_Temperatura_C                  0.008984         0.020483            0.439           0.661
# L7.PatioLateral_Humedad_Relativa_%             0.008795         0.004657            1.889           0.059
# L7.ExteriorFachada_Temperatura_C              -0.047444         0.023522           -2.017           0.044
# L7.ExteriorFachada_Humedad_Relativa_%         -0.003901         0.006604           -0.591           0.555
# L8.Consumo_Total_kWhs                         -0.034831         0.031771           -1.096           0.273
# L8.CuartoPrincipal_Temperatura_C              -0.040651         0.018019           -2.256           0.024
# L8.CuartoPrincipal_Humedad_Relativa_%          0.004586         0.003475            1.320           0.187
# L8.Sala_Temperatura_C                          0.004917         0.033678            0.146           0.884
# L8.Sala_Humedad_Relativa_%                     0.008559         0.008735            0.980           0.327
# L8.Cocina_Temperatura_C                        0.026118         0.044110            0.592           0.554
# L8.Cocina_Humedad_Relativa_%                   0.000050         0.007352            0.007           0.995
# L8.PatioLateral_Temperatura_C                  0.027496         0.020397            1.348           0.178
# L8.PatioLateral_Humedad_Relativa_%            -0.001887         0.004657           -0.405           0.685
# L8.ExteriorFachada_Temperatura_C               0.040323         0.023450            1.719           0.086
# L8.ExteriorFachada_Humedad_Relativa_%          0.012452         0.006610            1.884           0.060
# L9.Consumo_Total_kWhs                         -0.008571         0.031625           -0.271           0.786
# L9.CuartoPrincipal_Temperatura_C               0.025919         0.017781            1.458           0.145
# L9.CuartoPrincipal_Humedad_Relativa_%         -0.002215         0.003433           -0.645           0.519
# L9.Sala_Temperatura_C                          0.012147         0.033409            0.364           0.716
# ...
# L1.Consumo_Total_kWhs                         -0.506535         0.151936           -3.334           0.001
# L1.CuartoPrincipal_Temperatura_C              -0.123699         0.072695           -1.702           0.089
# L1.CuartoPrincipal_Humedad_Relativa_%         -0.073796         0.015622           -4.724           0.000
# L1.Sala_Temperatura_C                         -0.452344         0.154032           -2.937           0.003
# L1.Sala_Humedad_Relativa_%                    -0.021063         0.042317           -0.498           0.619
# L1.Cocina_Temperatura_C                        0.474754         0.179905            2.639           0.008
# L1.Cocina_Humedad_Relativa_%                   0.027507         0.036358            0.757           0.449
# L1.PatioLateral_Temperatura_C                 -0.198825         0.084919           -2.341           0.019
# L1.PatioLateral_Humedad_Relativa_%             0.088888         0.020613            4.312           0.000
# L1.ExteriorFachada_Temperatura_C              -1.196112         0.101428          -11.793           0.000
# L1.ExteriorFachada_Humedad_Relativa_%          0.629500         0.029595           21.270           0.000
# L2.Consumo_Total_kWhs                         -0.332735         0.165036           -2.016           0.044
# L2.CuartoPrincipal_Temperatura_C              -0.181451         0.093782           -1.935           0.053
# L2.CuartoPrincipal_Humedad_Relativa_%          0.037172         0.018105            2.053           0.040
# L2.Sala_Temperatura_C                         -0.230373         0.174671           -1.319           0.187
# L2.Sala_Humedad_Relativa_%                    -0.037810         0.045175           -0.837           0.403
# L2.Cocina_Temperatura_C                        0.088242         0.228934            0.385           0.700
# L2.Cocina_Humedad_Relativa_%                   0.024283         0.038010            0.639           0.523
# L2.PatioLateral_Temperatura_C                  0.037401         0.106729            0.350           0.726
# L2.PatioLateral_Humedad_Relativa_%            -0.054609         0.024340           -2.244           0.025
# L2.ExteriorFachada_Temperatura_C               0.918629         0.120710            7.610           0.000
# L2.ExteriorFachada_Humedad_Relativa_%          0.134010         0.034316            3.905           0.000
# L3.Consumo_Total_kWhs                         -0.070426         0.165752           -0.425           0.671
# L3.CuartoPrincipal_Temperatura_C              -0.096829         0.094011           -1.030           0.303
# L3.CuartoPrincipal_Humedad_Relativa_%          0.029086         0.018151            1.603           0.109
# L3.Sala_Temperatura_C                         -0.002469         0.175392           -0.014           0.989
# L3.Sala_Humedad_Relativa_%                    -0.047172         0.045373           -1.040           0.299
# L3.Cocina_Temperatura_C                       -0.157941         0.230350           -0.686           0.493
# L3.Cocina_Humedad_Relativa_%                   0.085039         0.038221            2.225           0.026
# L3.PatioLateral_Temperatura_C                  0.303761         0.107224            2.833           0.005
# L3.PatioLateral_Humedad_Relativa_%             0.012057         0.024371            0.495           0.621
# L3.ExteriorFachada_Temperatura_C               0.271176         0.122411            2.215           0.027
# L3.ExteriorFachada_Humedad_Relativa_%         -0.051861         0.034440           -1.506           0.132
# L4.Consumo_Total_kWhs                          0.186804         0.165625            1.128           0.259
# L4.CuartoPrincipal_Temperatura_C               0.023313         0.094002            0.248           0.804
# L4.CuartoPrincipal_Humedad_Relativa_%          0.004710         0.018127            0.260           0.795
# L4.Sala_Temperatura_C                          0.176022         0.175790            1.001           0.317
# L4.Sala_Humedad_Relativa_%                     0.024610         0.045389            0.542           0.588
# L4.Cocina_Temperatura_C                        0.060117         0.230679            0.261           0.794
# L4.Cocina_Humedad_Relativa_%                  -0.055681         0.038228           -1.457           0.145
# L4.PatioLateral_Temperatura_C                 -0.100436         0.107119           -0.938           0.348
# L4.PatioLateral_Humedad_Relativa_%            -0.000751         0.024381           -0.031           0.975
# L4.ExteriorFachada_Temperatura_C              -0.138525         0.122336           -1.132           0.257
# L4.ExteriorFachada_Humedad_Relativa_%          0.060543         0.034431            1.758           0.079
# L5.Consumo_Total_kWhs                          0.159183         0.165699            0.961           0.337
# L5.CuartoPrincipal_Temperatura_C               0.074017         0.093922            0.788           0.431
# L5.CuartoPrincipal_Humedad_Relativa_%         -0.002632         0.018113           -0.145           0.884
# L5.Sala_Temperatura_C                         -0.057529         0.175763           -0.327           0.743
# L5.Sala_Humedad_Relativa_%                    -0.052780         0.045400           -1.163           0.245
# L5.Cocina_Temperatura_C                       -0.051695         0.230267           -0.225           0.822
# L5.Cocina_Humedad_Relativa_%                   0.056795         0.038232            1.486           0.137
# L5.PatioLateral_Temperatura_C                 -0.024393         0.106524           -0.229           0.819
# L5.PatioLateral_Humedad_Relativa_%            -0.016857         0.024282           -0.694           0.488
# L5.ExteriorFachada_Temperatura_C               0.039627         0.122377            0.324           0.746
# L5.ExteriorFachada_Humedad_Relativa_%          0.029172         0.034463            0.846           0.397
# L6.Consumo_Total_kWhs                          0.140814         0.165656            0.850           0.395
# L6.CuartoPrincipal_Temperatura_C               0.032486         0.094004            0.346           0.730
# L6.CuartoPrincipal_Humedad_Relativa_%         -0.009758         0.018118           -0.539           0.590
# L6.Sala_Temperatura_C                          0.000556         0.175582            0.003           0.997
# L6.Sala_Humedad_Relativa_%                    -0.030193         0.045391           -0.665           0.506
# L6.Cocina_Temperatura_C                        0.031060         0.230054            0.135           0.893
# L6.Cocina_Humedad_Relativa_%                   0.059636         0.038229            1.560           0.119
# L6.PatioLateral_Temperatura_C                 -0.053932         0.106435           -0.507           0.612
# L6.PatioLateral_Humedad_Relativa_%             0.003408         0.024227            0.141           0.888
# L6.ExteriorFachada_Temperatura_C               0.119935         0.122517            0.979           0.328
# L6.ExteriorFachada_Humedad_Relativa_%         -0.015556         0.034438           -0.452           0.651
# L7.Consumo_Total_kWhs                          0.270506         0.165759            1.632           0.103
# L7.CuartoPrincipal_Temperatura_C              -0.016401         0.094054           -0.174           0.862
# L7.CuartoPrincipal_Humedad_Relativa_%          0.018056         0.018120            0.997           0.319
# L7.Sala_Temperatura_C                          0.092264         0.175686            0.525           0.599
# L7.Sala_Humedad_Relativa_%                     0.061413         0.045446            1.351           0.177
# L7.Cocina_Temperatura_C                       -0.114943         0.229945           -0.500           0.617
# L7.Cocina_Humedad_Relativa_%                  -0.011091         0.038252           -0.290           0.772
# L7.PatioLateral_Temperatura_C                  0.101213         0.106763            0.948           0.343
# L7.PatioLateral_Humedad_Relativa_%            -0.003208         0.024274           -0.132           0.895
# L7.ExteriorFachada_Temperatura_C              -0.151555         0.122602           -1.236           0.216
# L7.ExteriorFachada_Humedad_Relativa_%         -0.021594         0.034421           -0.627           0.530
# L8.Consumo_Total_kWhs                          0.203166         0.165600            1.227           0.220
# L8.CuartoPrincipal_Temperatura_C               0.073949         0.093921            0.787           0.431
# L8.CuartoPrincipal_Humedad_Relativa_%          0.026644         0.018114            1.471           0.141
# L8.Sala_Temperatura_C                         -0.017581         0.175538           -0.100           0.920
# L8.Sala_Humedad_Relativa_%                    -0.084324         0.045528           -1.852           0.064
# L8.Cocina_Temperatura_C                        0.319748         0.229916            1.391           0.164
# L8.Cocina_Humedad_Relativa_%                   0.019705         0.038318            0.514           0.607
# L8.PatioLateral_Temperatura_C                 -0.101646         0.106314           -0.956           0.339
# L8.PatioLateral_Humedad_Relativa_%             0.010507         0.024272            0.433           0.665
# L8.ExteriorFachada_Temperatura_C               0.031487         0.122230            0.258           0.797
# L8.ExteriorFachada_Humedad_Relativa_%         -0.027822         0.034456           -0.807           0.419
# L9.Consumo_Total_kWhs                          0.029928         0.164837            0.182           0.856
# L9.CuartoPrincipal_Temperatura_C              -0.000509         0.092680           -0.005           0.996
# L9.CuartoPrincipal_Humedad_Relativa_%          0.048530         0.017892            2.712           0.007
# L9.Sala_Temperatura_C                         -0.258891         0.174138           -1.487           0.137
# L9.Sala_Humedad_Relativa_%                     0.083696         0.045287            1.848           0.065
# L9.Cocina_Temperatura_C                       -0.168968         0.226501           -0.746           0.456
# L9.Cocina_Humedad_Relativa_%                   0.072697         0.038080            1.909           0.056
# L9.PatioLateral_Temperatura_C                  0.105484         0.105745            0.998           0.319
# L9.PatioLateral_Humedad_Relativa_%             0.015177         0.024231            0.626           0.531
# L9.ExteriorFachada_Temperatura_C              -0.137810         0.122243           -1.127           0.260
# L9.ExteriorFachada_Humedad_Relativa_%         -0.094727         0.034147           -2.774           0.006
# L10.Consumo_Total_kWhs                         0.100104         0.153397            0.653           0.514
# L10.CuartoPrincipal_Temperatura_C             -0.087866         0.065878           -1.334           0.182
# L10.CuartoPrincipal_Humedad_Relativa_%         0.029142         0.013839            2.106           0.035
# L10.Sala_Temperatura_C                        -0.120344         0.155459           -0.774           0.439
# L10.Sala_Humedad_Relativa_%                   -0.103603         0.039596           -2.617           0.009
# L10.Cocina_Temperatura_C                       0.413159         0.184969            2.234           0.026
# L10.Cocina_Humedad_Relativa_%                  0.039711         0.036894            1.076           0.282
# L10.PatioLateral_Temperatura_C                 0.127491         0.086120            1.480           0.139
# L10.PatioLateral_Humedad_Relativa_%           -0.015754         0.019726           -0.799           0.424
# L10.ExteriorFachada_Temperatura_C              0.220028         0.104210            2.111           0.035
# L10.ExteriorFachada_Humedad_Relativa_%         0.026291         0.029310            0.897           0.370
# =========================================================================================================
#
# Correlation matrix of residuals
#                                       Consumo_Total_kWhs  CuartoPrincipal_Temperatura_C  CuartoPrincipal_Humedad_Relativa_%  Sala_Temperatura_C  Sala_Humedad_Relativa_%  Cocina_Temperatura_C  Cocina_Humedad_Relativa_%  PatioLateral_Temperatura_C  PatioLateral_Humedad_Relativa_%  ExteriorFachada_Temperatura_C  ExteriorFachada_Humedad_Relativa_%
# Consumo_Total_kWhs                              1.000000                      -0.257127                           -0.184367           -0.282868                -0.129939             -0.093760                  -0.075371                    0.001941                        -0.049706                       0.004192                           -0.021185
# CuartoPrincipal_Temperatura_C                  -0.257127                       1.000000                            0.772515           -0.050037                -0.013747             -0.031904                   0.010221                    0.095737                        -0.066512                       0.314522                           -0.153306
# CuartoPrincipal_Humedad_Relativa_%             -0.184367                       0.772515                            1.000000           -0.090295                 0.159421             -0.127398                   0.189841                   -0.091023                         0.136119                       0.101825                            0.060019
# Sala_Temperatura_C                             -0.282868                      -0.050037                           -0.090295            1.000000                 0.254877              0.720679                   0.419090                    0.222904                        -0.151415                       0.162650                           -0.161044
# Sala_Humedad_Relativa_%                        -0.129939                      -0.013747                            0.159421            0.254877                 1.000000              0.101821                   0.786295                   -0.149871                         0.284572                      -0.092616                            0.222731
# Cocina_Temperatura_C                           -0.093760                      -0.031904                           -0.127398            0.720679                 0.101821              1.000000                   0.075820                    0.421421                        -0.282987                       0.243269                           -0.241167
# Cocina_Humedad_Relativa_%                      -0.075371                       0.010221                            0.189841            0.419090                 0.786295              0.075820                   1.000000                   -0.173113                         0.260729                      -0.049419                            0.169890
# PatioLateral_Temperatura_C                      0.001941                       0.095737                           -0.091023            0.222904                -0.149871              0.421421                  -0.173113                    1.000000                        -0.576636                       0.538296                           -0.502641
# PatioLateral_Humedad_Relativa_%                -0.049706                      -0.066512                            0.136119           -0.151415                 0.284572             -0.282987                   0.260729                   -0.576636                         1.000000                      -0.401221                            0.554405
# ExteriorFachada_Temperatura_C                   0.004192                       0.314522                            0.101825            0.162650                -0.092616              0.243269                  -0.049419                    0.538296                        -0.401221                       1.000000                           -0.813861
# ExteriorFachada_Humedad_Relativa_%             -0.021185                      -0.153306                            0.060019           -0.161044                 0.222731             -0.241167                   0.169890                   -0.502641                         0.554405                      -0.813861                            1.000000

# %%
# Predicción y Evaluación
lag_order = best_model.k_ar
forecast_input = train_data.values[-lag_order:]
predictions = best_model.forecast(y=forecast_input, steps=len(test_data))

# Convertir las predicciones a DataFrame
predicted_df = pd.DataFrame(predictions, index=test_data.index, columns=test_data.columns)

# Calcular el error cuadrático medio (MSE) para 'Consumo_Total_kWhs'
mse = np.mean((predicted_df['Consumo_Total_kWhs'] - test_data['Consumo_Total_kWhs'])**2)
print(f'Error cuadrático medio (MSE) para Consumo_Total_kWhs: {mse}')
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 69, Finished, Available, Finished)
# Error cuadrático medio (MSE) para Consumo_Total_kWhs: 0.12743981091476747

# %%
plt.figure(figsize=(12, 6))
plt.plot(test_data['Consumo_Total_kWhs'], label='Valores Reales')
plt.plot(predicted_df['Consumo_Total_kWhs'], label='Predicciones', color='red')
plt.title('Predicción con VAR')
plt.xlabel('Tiempo')
plt.ylabel('Consumo Total')
plt.legend()
plt.show()
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 6, 70, Finished, Available, Finished)

# %% [markdown]
# # Red Neuronal Recurrente

# %%
datos_rnn = datos_var_modelo.drop(['FechaHora'],axis = 1)
datos_rnn.columns
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 49, Finished, Available, Finished)
# Index(['Consumo_Total_kWhs', 'CuartoPrincipal_Temperatura_C',
#        'CuartoPrincipal_Humedad_Relativa_%', 'Sala_Temperatura_C',
#        'Sala_Humedad_Relativa_%', 'Cocina_Temperatura_C',
#        'Cocina_Humedad_Relativa_%', 'PatioLateral_Temperatura_C',
#        'PatioLateral_Humedad_Relativa_%', 'ExteriorFachada_Temperatura_C',
#        'ExteriorFachada_Humedad_Relativa_%'],
#       dtype='object')

# %%
datos_rnn = datos_var_modelo.drop(['FechaHora'],axis = 1)
scaler = MinMaxScaler(feature_range=(0, 1))
datos_normalizados = scaler.fit_transform(datos_rnn)

# Convertir a DataFrame para un manejo más sencillo
datos_normalizados = pd.DataFrame(datos_normalizados, columns=['Consumo_Total_kWhs', 'CuartoPrincipal_Temperatura_C',
       'CuartoPrincipal_Humedad_Relativa_%', 'Sala_Temperatura_C',
       'Sala_Humedad_Relativa_%', 'Cocina_Temperatura_C',
       'Cocina_Humedad_Relativa_%', 'PatioLateral_Temperatura_C',
       'PatioLateral_Humedad_Relativa_%', 'ExteriorFachada_Temperatura_C',
       'ExteriorFachada_Humedad_Relativa_%'])

# Paso 2: Estructura de los Datos para RNN
def crear_serie_tiempo(datos, look_back=24):
    X, y = [], []
    for i in range(len(datos) - look_back):
        X.append(datos[i:i + look_back, 1:])  # Variables predictoras
        y.append(datos[i + look_back, 0])  # Variable a predecir (Consumo_Total_kWhs)
    return np.array(X), np.array(y)

# Configurar los datos para entrenamiento y prueba
look_back = 24  # Usamos 24 horas anteriores para predecir la siguiente
train_size = int(len(datos_normalizados) * 0.8)

# Convertir los datos a numpy array
datos_np = datos_normalizados.values

# Dividir en entrenamiento y prueba
train_data = datos_np[:train_size]
test_data = datos_np[train_size:]

# Crear las series de tiempo para entrenamiento y prueba
X_train, y_train = crear_serie_tiempo(train_data, look_back)
X_test, y_test = crear_serie_tiempo(test_data, look_back)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 50, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [99], line 2
#       1 datos_rnn = datos_var_modelo.drop(['FechaHora'],axis = 1)
# ----> 2 scaler = MinMaxScaler(feature_range=(0, 1))
#       3 datos_normalizados = scaler.fit_transform(datos_rnn)
#       5 # Convertir a DataFrame para un manejo más sencillo
#
# NameError: name 'MinMaxScaler' is not defined

# %%
from tensorflow.keras.layers import Dropout
# Construcción del Modelo LSTM
model = Sequential()

# Capa LSTM
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))  # Regularización para prevenir overfitting

model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))

# Capa de salida
model.add(Dense(1))

# Compilar el modelo
model.compile(optimizer='adam', loss='mean_squared_error')

early_stopping = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True, verbose=1)

# Paso 4: Entrenamiento del Modelo
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, shuffle=False, verbose=2, 
callbacks=[early_stopping])

# %%
# Evaluación del Modelo
# Realizar predicciones
y_pred = model.predict(X_test)

# Desnormalizar los resultados
y_test_original = scaler.inverse_transform(np.concatenate((y_test.reshape(-1, 1), np.zeros((len(y_test), datos_np.shape[1] - 1))), axis=1))[:, 0]
y_pred_original = scaler.inverse_transform(np.concatenate((y_pred, np.zeros((len(y_pred), datos_np.shape[1] - 1))), axis=1))[:, 0]

# Calcular el error cuadrático medio (MSE)
mse = np.mean((y_pred_original - y_test_original) ** 2)
print(f'Error cuadrático medio (MSE): {mse}')
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 52, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [103], line 3
#       1 # Evaluación del Modelo
#       2 # Realizar predicciones
# ----> 3 y_pred = model.predict(X_test)
#       5 # Desnormalizar los resultados
#       6 y_test_original = scaler.inverse_transform(np.concatenate((y_test.reshape(-1, 1), np.zeros((len(y_test), datos_np.shape[1] - 1))), axis=1))[:, 0]
#
# NameError: name 'model' is not defined

# %%
# Resultados: 
plt.figure(figsize=(12, 6))
plt.plot(y_test_original, label='Valores Reales')
plt.plot(y_pred_original, label='Predicciones', color='red')
plt.title('Predicción de Consumo Total con LSTM')
plt.xlabel('Tiempo')
plt.ylabel('Consumo Total')
plt.legend()
plt.show()
# Out:
# StatementMeta(, , , Cancelled, , Cancelled)

# %% [markdown]
# # Predicciones

# %%
from tensorflow.keras.models import load_model
model = load_model('modelo_completo.h5')
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 7, 53, Finished, Available, Finished)
# 2024-09-09 13:57:18.916169: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-09 13:57:18.917485: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Transformaciones: 
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Escalamos los datos entre 0 y 1 para entrenar el modelo:
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train.values.reshape(-1, 1))


# Función para crear secuencias de entrada (X) y salida (y)
def create_sequences(data, time_step=24):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 5, 14, Finished, Available, Finished)

# %%
# Fecha Consumo
# test = data['Consumo']
# Escalar los datos de prueba
test_scaled = scaler.transform(test.values.reshape(-1, 1))

time_step = 24

# Crear secuencias para el conjunto de prueba
X_test, y_test = create_sequences(test_scaled, time_step)

# Reshape de los datos de prueba
X_test_reshaped = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 5, 15, Finished, Available, Finished)

# %% [markdown]
# # Predicción:

# %%
# Realizar predicciones
predictions = model.predict(X_test_reshaped)

# Invertir la escala de las predicciones
predictions_inverted = scaler.inverse_transform(predictions)
y_test_inverted = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 5, 16, Finished, Available, Finished)
# 3/3 [==============================] - 3s 25ms/step

# %%
y_test_inverted[0:10]
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 5, 21, Finished, Available, Finished)
# array([[0.1771],
#        [0.4571],
#        [0.3635],
#        [0.2525],
#        [0.194 ],
#        [0.131 ],
#        [0.1317],
#        [0.1667],
#        [0.1198],
#        [0.1117]])

# %%
print(len(y_test_inverted))
print(len(predictions_inverted))
# dataframe = concat(Fecha, test, y_test_inverted, fechaPrediccion)
# Guardar en spark dataframe.
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 5, 23, Finished, Available, Finished)
# 78
# 78

# %%
a = [[y_test_inverted],[predictions_inverted]]
a = np.array(a)
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 5, 32, Finished, Available, Finished)

# %%
pd.concat([y_test_inverted,predictions_inverted])
# Out:
# StatementMeta(a785e961-31e2-46cf-9273-e2d4c9410c25, 5, 31, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 pd.concat([y_test_inverted,predictions_inverted])
#
# File ~/cluster-env/env/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/cluster-env/env/lib/python3.10/site-packages/pandas/core/reshape/concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~/cluster-env/env/lib/python3.10/site-packages/pandas/core/reshape/concat.py:458, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     453     if not isinstance(obj, (ABCSeries, ABCDataFrame)):
#     454         msg = (
#     455             f"cannot concatenate object of type '{type(obj)}'; "
#     456             "only Series and DataFrame objs are valid"
#     457         )
# --> 458         raise TypeError(msg)
#     460     ndims.add(obj.ndim)
#     462 # get the sample
#     463 # want the highest ndim that we have, and must be non-empty
#     464 # unless all objs are empty
#
# TypeError: cannot concatenate object of type '<class 'numpy.ndarray'>'; only Series and DataFrame objs are valid
